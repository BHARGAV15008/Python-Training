# %% [markdown]
# # Working With Matpltlib

# %% [markdown]
# ## Installing Library

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## Bar Plot

# %%
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import numpy as np
import random

# %%
# also we have to assign name as well

plt.title("BAR GRAPH on X-axis and Y-axis")
plt.xlabel("ODD NUMBER", fontsize=15)
plt.ylabel("POWER of 2")

list_1 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

# plt_show = plt.bar(list_1, list_2, width=0.8, color="y")
# c = ["y", "b", "g", "black", "m"]
# plt.bar(list_1, list_2, width=0.4, color=c, align="edge")   # align="centre", by default centre
# plt.bar(list_1, list_2, width=0.4, color=c, align="edge", edgecolor="r", linewidth=2, linestyle=":", alpha=0.5)
plt.bar(list_1, list_2, width=0.4, label="ODD vs POWER")
plt.legend()
plt.show()

# %%
# also we have to assign name as well

plt.title("BAR GRAPH on X-axis and Y-axis")
plt.xlabel("ODD NUMBER", fontsize=15)
plt.ylabel("POWER of 2")

list_1 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

list_3 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_4 = [4, 8, 12, 20, 36]   # this plot show on y-axis

plt.bar(list_3, list_4, width=0.4, label="ODD vs POwER + 4")
plt.bar(list_1, list_2, width=0.4, label="ODD vs POWER")

plt.legend()
plt.show()

# %%
# also we have to assign name as well
plt.title("BAR GRAPH on X-axis and Y-axis")
plt.xlabel("ODD NUMBER", fontsize=15)
plt.ylabel("POWER of 2")

list_1 = ["one", "two", "three", "four", "five"]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

width=0.4
p = np.arange(len(list_1))
adjust_p = [j+width for j in p]

# list_3 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_4 = [4, 8, 12, 20, 36]   # this plot show on y-axis

plt.bar(p, list_4, width, label="ODD vs POwER + 4")
plt.bar(adjust_p, list_2, width, label="ODD vs POWER")

plt.xticks(p+width/2, list_1, rotation=10)
plt.legend()
plt.show()

# %%
# also we have to assign name as well

plt.title("BAR GRAPH on X-axis and Y-axis")
plt.xlabel("ODD NUMBER", fontsize=15)
plt.ylabel("POWER of 2")

list_1 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

list_4 = [4, 8, 12, 20, 36]   # this plot show on y-axis

plt.barh(list_1, list_4, label="ODD vs POwER + 4")
plt.bar(list_1, list_2, width=0.4, label="ODD vs POWER")

plt.legend()
plt.show()

# %%
# also we have to assign name as well

plt.title("BAR GRAPH on X-axis and Y-axis")
plt.xlabel("ODD NUMBER", fontsize=15)
plt.ylabel("POWER of 2")

list_1 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

list_4 = [4, 8, 12, 20, 36]   # this plot show on y-axis

plt.barh(list_1, list_4, label="ODD vs POwER + 4")
plt.barh(list_1, list_2, label="ODD vs POWER")

plt.legend()
plt.show()

# %%
# also we have to assign name as well
plt.title("BAR GRAPH on X-axis and Y-axis")
plt.xlabel("ODD NUMBER", fontsize=15)
plt.ylabel("POWER of 2")

list_1 = ["one", "two", "three", "four", "five"]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

width=0.4
p = np.arange(len(list_1))
adjust_p = [j+width for j in p]

# list_3 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_4 = [4, 8, 12, 20, 36]   # this plot show on y-axis

plt.barh(p, list_4, width, label="ODD vs POwER + 4")
plt.barh(adjust_p, list_2, width, label="ODD vs POWER")

plt.yticks(p+width/2, list_1, rotation=10)
plt.legend()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# also we have to assign name as well
plt.title("Scatter GRAPH on X-axis and Y-axis", fontsize=15)
plt.xlabel("ODD NUMBER", fontsize=10)
plt.ylabel("POWER of 2")

list_1 = ["one", "two", "three", "four", "five"]     # this plot show on x-axis
list_2 = [2, 4, 8, 16, 32]   # this plot show on y-axis

width=0.4
p = np.arange(len(list_1))
adjust_p = [j+width for j in p]

# list_3 = [1, 2, 3, 4, 5]     # this plot show on x-axis
list_4 = [4, 8, 12, 20, 36]   # this plot show on y-axis

c = ["y", "b", "g", "black", "m"]
c_codes = [20, 35, 49, 66, 79]
s = [250, 350, 450, 550, 650]
# plt.scatter(p, list_4, label="ODD vs POwER + 4", color=c, s=s, alpha=0.4)  # use color or c, size-c
# plt.scatter(p, list_4, label="ODD vs POwER + 4", s=s, marker="*", edgecolor="r", linewidth=2)
plt.scatter(p, list_4, label="ODD vs POwER + 4", s=s, marker="*")  # colormap-cmap, also used colorbar
# plt.colorbar()
t = plt.colorbar()
t.set_label("color bar", fontsize=15)

plt.scatter(adjust_p, list_2, label="ODD vs POWER", c=c_codes)

# plt.xticks(p+width/2, list_1, rotation=10)
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram

# %%
x_data = [2, 4, 3, 9, 10, 4, 12]
y_data = np.random.randint(10,60,(50))
y_data
# Out:
# array([34, 18, 10, 20, 21, 35, 37, 56, 17, 43, 54, 46, 57, 30, 45, 36, 56,
#        57, 50, 51, 58, 19, 48, 18, 28, 18, 11, 59, 44, 35, 55, 43, 50, 52,
#        22, 52, 27, 48, 33, 36, 20, 17, 47, 17, 42, 48, 50, 44, 38, 15])

# %%
y_data_formate = [34, 18, 10, 20, 21, 35, 37, 56, 17, 43, 54, 46, 57, 30, 45, 36, 56,
       57, 50, 51, 58, 19, 48, 18, 28, 18, 11, 59, 44, 35, 55, 43, 50, 52,
       22, 52, 27, 48, 33, 36, 20, 17, 47, 17, 42, 48, 50, 44, 38, 15]

# %%
y_data_formate
# Out:
# [34,
#  18,
#  10,
#  20,
#  21,
#  35,
#  37,
#  56,
#  17,
#  43,
#  54,
#  46,
#  57,
#  30,
#  45,
#  36,
#  56,
#  57,
#  50,
#  51,
#  58,
#  19,
#  48,
#  18,
#  28,
#  18,
#  11,
#  59,
#  44,
#  35,
#  55,
#  43,
#  50,
#  52,
#  22,
#  52,
#  27,
#  48,
#  33,
#  36,
#  20,
#  17,
#  47,
#  17,
#  42,
#  48,
#  50,
#  44,
#  38,
#  15]

# %%
plt.title("HISTOGRAM")
plt.xlabel("X_AXIS DATA")
plt.ylabel("Y_AXIS DATA")

bins_data = [10, 20, 30, 40, 50, 60]
# plt.hist(y_data_formate, color="g", bins=bins_data, edgecolor="m")
# plt.hist(y_data_formate, "auto", (0,200), edgecolor="m")
# plt.hist(y_data_formate, color="g", edgecolor="m")
# plt.hist(y_data_formate, color="g", edgecolor="m", cumulative=1) # cumulative= -1 reverse
# plt.hist(y_data_formate, color="g", edgecolor="m", bottom=15)
# plt.hist(y_data_formate, color="g", edgecolor="m", align="mid") # mid left right
# plt.hist(y_data_formate, color="g", edgecolor="m", histtype="step") # step stepfilled barstacked bar
# plt.hist(y_data_formate, color="g", edgecolor="m", orientation="horizontal")
# plt.hist(y_data_formate, color="g", bins=bins_data, edgecolor="m", rwidth=.8)
plt.hist(y_data_formate, color="g", bins=bins_data, edgecolor="m", log="true")

plt.show()

# %%
plt.hist(x_data, label="python data")

plt.axvline(5, color="r", label="Axvline")
plt.grid()

plt.legend()
plt.show()

# %% [markdown]
# ## Pie Plot

# %%
x_dataPie = [10, 20, 30, 40, 50]
y_dataPie = ["C", "C++", "Python", "Java", "JavaScript"]

# %%
plt.pie(x_dataPie, labels=y_dataPie)
# Out:
# ([<matplotlib.patches.Wedge at 0x28a44fc06d0>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'C'),
#   Text(0.7360436312779136, 0.817459340184711, 'C++'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Python'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'Java'),
#   Text(0.5500001932481627, -0.9526278325909777, 'JavaScript')])

# %%
ex = [0.3, 0.0, 0.0, 0.0, 0.0]
c = ["y", "m", "r", "b", "g"]

# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex)
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, autopct="%0.1f%%")
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, shadow="true")
plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, radius=1.5)

plt.show()

# %%
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, labeldistance=1.1)
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, startangle=90)
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, autopct="%0.1f%%", explode=ex, textprops={"fontsize":15})
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, counterclock=False)
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, shadow=True, wedgeprops={"linewidth":2, "width":1.5, "edgecolor":"y"})
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, center=(3,3))
# plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex, rotatelabels=True)
plt.pie(x_dataPie, labels=y_dataPie, colors=c, explode=ex)

plt.title("Pie chart")
plt.legend(loc=1)
plt.show()

# %%
plt.pie([1])
plt.show()

# %%
x_dataPie2 = [30, 10, 40, 60, 50]
plt.pie(x_dataPie, labels=y_dataPie, colors=c)
plt.pie(x_dataPie2, radius=.6)

plt.show()

# %%
x_dataPie2 = [30, 10, 40, 60, 50]
plt.pie(x_dataPie, labels=y_dataPie, colors=c)
plt.pie([1], colors="w", radius=.7)

plt.show()

# %%
x_dataPie2 = [30, 10, 40, 60, 50]
plt.pie(x_dataPie, labels=y_dataPie, colors=c)
plt.pie(x_dataPie2, radius=.6)

cr = plt.Circle(xy=(0, 0), radius=.9, facecolor="w")
plt.gca().add_artist(cr)

plt.show()

# %% [markdown]
# ## Stem Plot

# %%
x_dataStem = [1, 2, 3, 4, 5, 6, 7]
y_dataStem = [3, 5, 2, 6, 1, 8, 9]

# plt.stem(x_dataStem, y_dataStem)
# plt.stem(x_dataStem, y_dataStem, linefmt=":", markerfmt="r*")
# plt.stem(x_dataStem, y_dataStem, bottom=2)
# plt.stem(x_dataStem, y_dataStem, bottom=9)
# plt.stem(x_dataStem, y_dataStem, basefmt="g", label="python", use_line_collection=False)
plt.stem(x_dataStem, y_dataStem, orientation="horizontal")

# plt.legend()
plt.show()

# %% [markdown]
# ## Box and Whisker Plot

# %%
x_dataBox = [10, 20, 30, 40, 50, 60, 70]

# plt.boxplot(x_dataBox)
# plt.boxplot(x_dataBox, notch=True)
# plt.boxplot(x_dataBox, vert=False, labels=["python"])
# plt.boxplot(x_dataBox, widths=0.5, labels=["python"], patch_artist=True)
# plt.boxplot(x_dataBox, showmeans=True, labels=["python"])
plt.boxplot(x_dataBox, )

plt.show()

# %%
x_dataBox = [10, 20, 30, 40, 50, 60, 70, 120]

plt.boxplot(x_dataBox, showmeans=True, labels=["python"])

plt.show()

# %%
# x_dataBox = [10, 20, 30, 40, 50, 60, 70, 120]
x_dataBox = [10, 20, 30, 40, 50, 60, 70]

# plt.boxplot(x_dataBox, showmeans=True, whis=2)
# plt.boxplot(x_dataBox, sym="g*")
plt.boxplot(x_dataBox, labels=["python"], boxprops=dict(color="r"), capprops=dict(color="g"), whiskerprops=dict(color="y"),
           flierprops=dict(markeredgecolor="y"))

plt.show()

# %%
x_dataBox1 = [10, 20, 40, 60, 80, 100]
x_dataBox2 = [10, 30, 50, 70, 90, 110]

dataBoxs = [x_dataBox, x_dataBox1, x_dataBox2]

plt.boxplot(dataBoxs, labels=["python", "Java", "C++"], boxprops=dict(color="r"), 
            capprops=dict(color="g"), whiskerprops=dict(color="y"))

plt.show()

# %% [markdown]
# ## Area vs Stack Plot

# %%
x_dataStack = [1, 2, 3, 4, 5, 6, 7]
y_dataStack = [2, 4, 3, 4, 5, 2, 9]

plt.stackplot(x_dataStack, y_dataStack)

plt.show()

# %%
x_dataStack = [1, 2, 3, 4, 5, 6, 7]
y_dataStack = [2, 4, 3, 1, 6, 8, 9]
y_dataStack1 = [1, 3, 2, 1, 5, 2, 7]
y_dataStack2 = [3, 5, 4, 3, 7, 7, 8]

label = ["area1", "area2", "area3"]

# plt.stackplot(x_dataStack, y_dataStack2, y_dataStack, y_dataStack1, labels=label)
# plt.stackplot(x_dataStack, y_dataStack2, y_dataStack, y_dataStack1, labels=label, colors=["y", "g", "r"])
# plt.stackplot(x_dataStack, y_dataStack2, y_dataStack, y_dataStack1, labels=label, baseline="sym") # zero, wiggler, sym - baseline
plt.stackplot(x_dataStack, y_dataStack2, y_dataStack, y_dataStack1, labels=label)

plt.title("Area graph")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Step Plot

# %%
x_dataStep = [1, 2, 3, 4, 5, 6, 7]
y_dataStep = [8, 4, 6, 7, 2, 9, 5]

plt.step(x_dataStep, y_dataStep, marker="*", color="r", ms=15, mfc="g", label="Python")

plt.legend()
plt.title("STEP GRAPH")
plt.xlabel("X_axis")
plt.ylabel("Y_sxis")
plt.grid()
plt.show()

# %% [markdown]
# ## Fill Between Plot

# %%
x_dataFill = np.array([1, 2, 3, 4, 5, 6, 7])
y_dataFill1 = np.array([8, 4, 6, 7, 2, 9, 5])

plt.plot(x_dataFill, y_dataFill1, color="r")
# plt.fill_between(x_dataFill, y_dataFill1)
# plt.fill_between(x=[2,5], y1=2, y2=4, color="g")
plt.fill_between(x_dataFill, y_dataFill1, color="g", where=(x_dataFill>=2) & (x_dataFill<=5), alpha=.3)

plt.show()

# %% [markdown]
# ## Sub Plot

# %%
x_dataSub = np.array([1, 2, 3, 4, 5, 6, 7])
y_dataSub1 = np.array([8, 4, 6, 7, 2, 9, 5])

plt.subplot(2,2,4)
plt.plot(x_dataSub, y_dataSub1, color="r")

plt.subplot(2,2,1)
plt.pie([1,2,3,4,3], radius=.8)

plt.subplot(2,2,2)
plt.pie([5,6,11], radius=.8)

plt.subplot(2,2,3)
plt.bar(x_dataSub, y_dataSub1, color="g")


plt.show()

# %%
x_dataSub = np.array([1, 2, 3, 4, 5, 6, 7])
y_dataSub1 = np.array([8, 4, 6, 7, 2, 9, 5])

plt.subplot(1,4,4)
plt.plot(x_dataSub, y_dataSub1, color="r")

plt.subplot(1,4,1)
plt.pie([1,2,3,4,3], radius=1)

plt.subplot(1,4,2)
plt.pie([5,6,11], radius=1)

plt.subplot(1,4,3)
plt.bar(x_dataSub, y_dataSub1, color="g")


plt.show()

# %%
x_dataSub = np.array([1, 2, 3, 4, 5, 6, 7])
y_dataSub1 = np.array([8, 4, 6, 7, 2, 9, 5])

plt.subplot(4,1,4)
plt.plot(x_dataSub, y_dataSub1, color="r")

plt.subplot(4,1,1)
plt.pie([1,2,3,4,3])

plt.subplot(4,1,2)
plt.pie([5,6,11], radius=1)

plt.subplot(4,1,3)
plt.bar(x_dataSub, y_dataSub1, color="g")


plt.show()

# %% [markdown]
# ## Savefig

# %%
x_dataSub = np.array([1, 2, 3, 4, 5, 6, 7])
y_dataSub1 = np.array([8, 4, 6, 7, 2, 9, 5])

plt.subplot(2,2,4)
plt.plot(x_dataSub, y_dataSub1, color="r")

plt.subplot(2,2,1)
plt.pie([1,2,3,4,3], radius=.8)

plt.subplot(2,2,2)
plt.pie([5,6,11], radius=.8)

plt.subplot(2,2,3)
plt.bar(x_dataSub, y_dataSub1, color="b")

# plt.savefig("Subplot.png", dpi=200, facecolor="g")
# plt.savefig("Subplot.png", dpi=200, facecolor="g", transparent=False)
plt.savefig("Subplot.png", dpi=200, facecolor="g", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Axis in Plot

# %%
x_dataAxes = np.array([1, 2, 3, 4, 5])
y_dataAxes = np.array([8, 4, 6, 7, 5])

plt.plot(x_dataAxes, y_dataAxes, color="r")

# plt.xticks(x_dataAxes)
# plt.xticks(x_dataAxes, labels=["c", "c++", "python", "java", "js"])
# plt.yticks(y_dataAxes)

# plt.xlim(0,10)
# plt.ylim(0.10)

plt.axis([0,7,0,8])

plt.show()

# %% [markdown]
# ## Text Formate

# %%
x_dataText = np.array([1, 2, 3, 4, 5])
y_dataText = np.array([8, 4, 6, 7, 5])

plt.plot(x_dataText, y_dataText, color="r")

plt.title("Play with Text", fontsize=15)
plt.xlabel("X AXIS", fontsize=15)
plt.ylabel("Y AXIS", fontsize=15)

plt.text(2, 5, "JavaScript", fontsize=15, style="italic", bbox={"facecolor":"g"})
plt.annotate("python", xy=(1, 7), xytext=(4,4), arrowprops=dict(facecolor="black", shrink=100))
plt.legend(["up"], facecolor="g", edgecolor="b", shadow=True, framealpha=.4)

plt.show()
